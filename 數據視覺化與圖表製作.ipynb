# %% [markdown]
# <a href="https://colab.research.google.com/github/passer87/aidata/blob/main/%E6%95%B8%E6%93%9A%E8%A6%96%E8%A6%BA%E5%8C%96%E8%88%87%E5%9C%96%E8%A1%A8%E8%A3%BD%E4%BD%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#數據視覺化與圖表製作


import matplotlib.pyplot as plt

# 創建數據
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# 繪製折線圖
plt.plot(x, y, marker='o')
plt.title('Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

import matplotlib.pyplot as plt

# 創建數據
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 3, 8, 4]

# 繪製柱狀圖
plt.bar(categories, values, color='blue')
plt.title('Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

import matplotlib.pyplot as plt
import numpy as np

# 創建數據
data = np.random.randn(1000)

# 繪製直方圖
plt.hist(data, bins=30, color='green', edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

import matplotlib.pyplot as plt

# 創建數據
x = np.random.rand(100)
y = np.random.rand(100)

# 繪製散點圖
plt.scatter(x, y, color='red')
plt.title('Scatter Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

import seaborn as sns
import matplotlib.pyplot as plt

# 創建數據
data = np.random.randn(100)

# 繪製箱線圖
sns.boxplot(data)
plt.title('Box Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 創建數據
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# 創建多圖表佈局
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# 繪製圖表
ax1.plot(x, y1, color='blue', label='Sine')
ax1.set_title('Sine Wave')
ax1.set_xlabel('X Axis')
ax1.set_ylabel('Y Axis')
ax1.legend()

ax2.plot(x, y2, color='green', label='Cosine')
ax2.set_title('Cosine Wave')
ax2.set_xlabel('X Axis')
ax2.set_ylabel('Y Axis')
ax2.legend()

plt.show()

# %%
pip install matplotlib seaborn
